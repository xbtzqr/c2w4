# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Radjen Hernández**
# Data Science

# %% [markdown]
# *I am interested in data science because i like to work with data*

# %% [markdown]
# ### The following code is an addition operator

# %%
a = 1
b = 2
add = a + b
print(add)
# Out:
# 3

# %% [markdown]
# ---
# ---
# ---
#
#   * one
#   * two
#   * three
#   1. a
#   2. b
#   3. c
#
# ID | Age | Gender
# :--- | :---: | :---:
# 1  |20  |M
# 2  |21  |F
# 3  |22  |M
#
#
# [ROSALIND](https://rosalind.info/)
# [Kaggle](https://www.kaggle.com)
# [stratascratch](https://www.stratascratch.com)
#
# ![Python logo](https://upload.wikimedia.org/wikipedia/commons/c/c3/Python-logo-notext.svg "Python")
# ![Jupyter logo](https://upload.wikimedia.org/wikipedia/commons/3/38/Jupyter_logo.svg "Jupyter")
# <img src="https://1000logos.net/wp-content/uploads/2020/08/MySQL-Logo.png" alt="MySQL logo" title="MySQL" width="200">
#
# ```python
# x = 1 + 1
# print x
# ```
# ```python
# z = 2 - 1
# print z
# ```
# ```python
# c = 3 * 2
# print c
# ```
# > abc
#
# > 123
#
# > !@#
#
# ~~abc~~
# ~~123~~
# ~~!@#~~
